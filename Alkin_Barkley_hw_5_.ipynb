# %% [markdown]
# <a href="https://colab.research.google.com/github/Alkinbark/Data-Wrangling1/blob/main/Alkin_Barkley_hw_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import python pacakages
import pandas as pd
print("import package libraries")
# Out:
# import package libraries

# %%
#load sheet
tree_census = pd.read_csv('trees.csv')

# %%
# look at the first five rows
tree_census.head()
# Out:
#    created_at  tree_id block_id  \
# 0  08/27/2015  180,683  348,711
# 1  09/03/2015  200,540  315,986
# 2  09/05/2015  204,026  218,365
# 3  09/05/2015  204,337  217,969
# 4  08/30/2015  189,565  223,043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...     28.0
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...     27.0
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...     50.0
# ...

# %%
#look at the last five rows
tree_census.tail()
# Out:
#        created_at  tree_id block_id  \
# 50084  09/23/2015  249,430  227,741
# 50085  09/24/2015  255,329  332,807
# 50086  09/22/2015  246,573  341,646
# 50087  09/24/2015  254,110  502,950
# 50088  09/24/2015  254,246  227,555
#
#                                            the_geom  tree_dbh  stump_diam  \
# 50084  POINT (-73.96974566542599 40.62211656320578)         3           0
# 50085  POINT (-73.74424744783633 40.68930935421922)        13           0
# 50086   POINT (-73.8905051413558 40.75809867764904)        28           0
# 50087  POINT (-73.92415232201832 40.82870759882272)        19           0
# 50088  POINT (-73.97011189412626 40.61457324688095)        24           0
#
#       curb_loc status health              spc_latin  ... st_assem st_senate  \
# 50084   OnCurb  Alive   Fair        Ulmus americana  ...     48.0      17.0
# 50085   OnCurb  Alive   Fair    Acer pseudoplatanus  ...     33.0      14.0
# ...

# %%
#list of column names
tree_census.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'Latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
#identify the size, number of rows and columns iin the dataset
tree_census.shape
# Out:
# (50089, 42)

# %%
#summary of the dataset
tree_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50089 entries, 0 to 50088
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  50089 non-null  object
#  1   tree_id     50089 non-null  object
#  2   block_id    50089 non-null  object
#  3   the_geom    50089 non-null  object
#  4   tree_dbh    50089 non-null  int64
#  5   stump_diam  50089 non-null  int64
#  6   curb_loc    50089 non-null  object
#  7   status      50089 non-null  object
#  8   health      47678 non-null  object
#  9   spc_latin   47679 non-null  object
#  10  spc_common  47679 non-null  object
#  11  steward     14953 non-null  object
#  12  guards      7810 non-null   object
#  13  sidewalk    47679 non-null  object
#  14  user_type   50088 non-null  object
#  15  problems    20586 non-null  object
#  16  root_stone  50088 non-null  object
#  17  root_grate  50088 non-null  object
#  18  root_other  50088 non-null  object
# ...

# %%
# health status of tress
tree_census.health.value_counts(dropna=False)
# Out:
# health
# Good    35979
# Fair     8992
# Poor     2707
# NaN      2411
# Name: count, dtype: int64

# %%
# get status on the trees
tree_census.status.value_counts(dropna=False)
# Out:
# status
# Alive    47679
# Stump     1388
# Dead      1022
# Name: count, dtype: int64

# %%
#subset of the original, removed columns not interested in
trees_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone', 'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe']]

#list the first 5 rows of the new subset
trees_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0  180,683         3           0   OnCurb  Alive   Fair
# 1  200,540        21           0   OnCurb  Alive   Fair
# 2  204,026         3           0   OnCurb  Alive   Good
# 3  204,337        10           0   OnCurb  Alive   Good
# 4  189,565        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  ...  \
# 0                         Acer rubrum        red maple     NaN    NaN  ...
# 1                   Quercus palustris          pin oak     NaN    NaN  ...
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN  ...
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN  ...
# 4                     Tilia americana  American linden     NaN    NaN  ...
#
#   problems root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# 0      NaN         No         No         No        No         No         No
# ...

# %%
#check for any null values
trees_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health         2411
# spc_latin      2410
# spc_common     2410
# steward       35136
# guards        42279
# sidewalk       2410
# user_type         1
# problems      29503
# root_stone        1
# root_grate        1
# root_other        1
# trnk_wire         1
# trnk_light        1
# trnk_other        1
# brnch_ligh        1
# brnch_shoe        1
# brnch_othe        1
# dtype: int64

# %%
#show all that none values in health, a lot of missing values NaN
tree_census.describe()
# Out:
#            tree_dbh    stump_diam       zipcode        cb_num      borocode  \
# count  50089.000000  50089.000000  50088.000000  50088.000000  50088.000000
# mean      11.338677      0.453153  10884.290768    324.452603      3.172217
# std        8.644915      3.310691    655.126899    122.781067      1.235812
# min        0.000000      0.000000     83.000000    101.000000      1.000000
# 25%        5.000000      0.000000  10312.000000    212.000000      2.000000
# 50%       10.000000      0.000000  11215.000000    315.000000      3.000000
# 75%       16.000000      0.000000  11365.000000    409.000000      4.000000
# max      425.000000    140.000000  11697.000000    503.000000      5.000000
#
#            cncldist      st_assem     st_senate       boro_ct      Latitude  \
# count  50088.000000  50088.000000  50088.000000  5.008800e+04  50088.000000
# mean      27.745288     51.102040     20.950327  3.216950e+06     40.710167
# ...

# %%
# generate histogram of data distribution
trees_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'tree_dbh'}>,
#         <Axes: title={'center': 'stump_diam'}>]], dtype=object)

# %%
# trees larger than 50
big_trees = trees_subset[trees_subset['tree_dbh']> 50]
big_trees.head()
# Out:
#        tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2385   168,583       425           0          OnCurb  Alive   Good
# 3724   199,546        51           0          OnCurb  Alive   Good
# 4874   139,665        72           0  OffsetFromCurb  Alive   Good
# 6711   209,349       122           0          OnCurb  Alive   Good
# 10053  215,075       169           0          OnCurb  Alive   Good
#
#                                 spc_latin       spc_common steward guards  \
# 2385                      Quercus bicolor  swamp white oak    1or2    NaN
# 3724                     Acer saccharinum     silver maple     NaN    NaN
# 4874                     Acer saccharinum     silver maple     NaN    NaN
# 6711                    Quercus palustris          pin oak     NaN    NaN
# 10053  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
#
#        ... problems root_stone root_grate root_other trnk_wire trnk_light  \
# ...

# %%
# box plot
tree_census.boxplot(column='tree_dbh', by='stump_diam')
# Out:
# <Axes: title={'center': 'tree_dbh'}, xlabel='stump_diam'>

# %%
# scatter plot
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter', x='tree_id', y='tree_dbh')
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>
